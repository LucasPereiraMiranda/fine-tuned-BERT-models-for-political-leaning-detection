# %%
import pandas as pd
import math

# %%
general_right_df = pd.read_csv('general_left.csv')
general_right_df
# Out:
#                     page_name  number_posts  number_comments
# 0         Sou esquerda e dai?          6703            19510
# 1   Diário do centro do mundo          7182            11256
# 2                  Brasil 247          6912            45122
# 3          Jornalistas Livres          7020            75704
# 4          Jovens de esquerda          6970            22975
# 5               Blog da Dilma          6583            72602
# 6            Quebrando o tabu          6797           337666
# 7               Revista Fórum          7135            18525
# 8             Esquerda Diário          7193             5050
# 9             Esquerda Online          6842           127345
# 10          Rede Brasil Atual          6943             2588

# %%
import matplotlib.pyplot as plt
import numpy as np # importing numpy
import matplotlib.dates as mdates
from matplotlib.ticker import ScalarFormatter

# Create figure and plot space
fig, ax = plt.subplots(figsize=(15, 12))

# Add x-axis and y-axis
#ax.bar(grouped_by_year['created_time'],
#    grouped_by_year['reactions_like'],
#       color='purple')

ax.bar(general_right_df['page_name'],general_right_df['number_posts'],
       color='#A52A2A')

# Set title and labels for axes
ax.set(xlabel="Nome da página",
       ylabel="Número de posts",
       title="Número de posts por página")

ax.set_xticklabels(general_right_df['page_name'],rotation='vertical');
plt.ticklabel_format(style='plain', axis='y')

for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                xytext=(0, 5), textcoords='offset points', ha='center', va='bottom') 

plt.show()
# Out:
# /tmp/ipykernel_52256/3690292119.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(general_right_df['page_name'],rotation='vertical');

# %%
import matplotlib.pyplot as plt
import numpy as np # importing numpy
import matplotlib.dates as mdates
from matplotlib.ticker import ScalarFormatter

# Create figure and plot space
fig, ax = plt.subplots(figsize=(15, 12))

# Add x-axis and y-axis
#ax.bar(grouped_by_year['created_time'],
#    grouped_by_year['reactions_like'],
#       color='purple')

ax.bar(general_right_df['page_name'],general_right_df['number_comments'],
       color='#A52A2A')

# Set title and labels for axes
ax.set(xlabel="Nome da página",
       ylabel="Número de comentários",
       title="Número de comentários por página")

ax.set_xticklabels(general_right_df['page_name'],rotation='vertical');
plt.ticklabel_format(style='plain', axis='y')

for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                xytext=(0, 5), textcoords='offset points', ha='center', va='bottom') 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_156806/1772580620.py in <module>
#      12 #       color='purple')
#      13
# ---> 14 ax.bar(general_right_df['page_name'],general_right_df['number_comments'],
#      15        color='#A52A2A')
#      16
#
# NameError: name 'general_right_df' is not defined

# %%
general_right_df['number_posts'].sum()
# Out:
# 76280

# %%
general_right_df['number_comments'].sum()
# Out:
# 738343
