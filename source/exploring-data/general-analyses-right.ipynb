# %%
import pandas as pd
import math

# %%
general_right_df = pd.read_csv('general_right.csv')
general_right_df
# Out:
#                                           page_name  number_posts  \
# 0                           Apoio a Policia Federal          6289
# 1                              Brasil acima de tudo          6436
# 2                                    Partido Brasil          6208
# 3                               SomostodosBolsonaro          6889
# 4                                  O Brasil Acordou          3649
# 5   Jair Bolsonaro 2022 a ultima Esperança da Nação          1393
# 6                              Jair bolsonaro #mito          5001
# 7                    Jair Bolsonaro Presidente 2018          5690
# 8                                 Jovens de direita          3036
# 9                          Bolsonaro Herói Nacional          4496
# 10                    Operação lava Jato - eu apoio           432
#
#     number_comments
# 0             39528
# 1             27264
# 2             50521
# 3            308254
# 4               928
# 5             70015
# 6            125437
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np # importing numpy
import matplotlib.dates as mdates
from matplotlib.ticker import ScalarFormatter

# Create figure and plot space
fig, ax = plt.subplots(figsize=(15, 12))

# Add x-axis and y-axis
#ax.bar(grouped_by_year['created_time'],
#    grouped_by_year['reactions_like'],
#       color='purple')

ax.bar(general_right_df['page_name'],general_right_df['number_posts'],
       color='#404080')

# Set title and labels for axes
ax.set(xlabel="Nome da página",
       ylabel="Número de posts",
       title="Número de posts por página")

ax.set_xticklabels(general_right_df['page_name'],rotation='vertical');
plt.ticklabel_format(style='plain', axis='y')

for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                xytext=(0, 5), textcoords='offset points', ha='center', va='bottom') 

plt.show()
# Out:
# /tmp/ipykernel_156607/935649558.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(general_right_df['page_name'],rotation='vertical');

# %%
import matplotlib.pyplot as plt
import numpy as np # importing numpy
import matplotlib.dates as mdates
from matplotlib.ticker import ScalarFormatter
# direita_numero_comentarios_por_pagina
# Create figure and plot space
fig, ax = plt.subplots(figsize=(15, 12))

# Add x-axis and y-axis
#ax.bar(grouped_by_year['created_time'],
#    grouped_by_year['reactions_like'],
#       color='purple')

ax.bar(general_right_df['page_name'],general_right_df['number_comments'],
       color='#A52A2A')

# Set title and labels for axes
ax.set(xlabel="Nome da página",
       ylabel="Número de comentários",
       title="Número de comentários por página")

ax.set_xticklabels(general_right_df['page_name'],rotation='vertical');
plt.ticklabel_format(style='plain', axis='y')

for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', xy=(rect.get_x()+rect.get_width()/2, height), 
                xytext=(0, 5), textcoords='offset points', ha='center', va='bottom') 

plt.show()
# Out:
# /tmp/ipykernel_156607/1772580620.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(general_right_df['page_name'],rotation='vertical');

# %%
general_right_df['number_posts'].sum()
# Out:
# 49519

# %%
general_right_df['number_comments'].sum()
# Out:
# 687857
